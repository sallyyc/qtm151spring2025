# %% [markdown]
# # Assignment 3

# %% [markdown]
# ## Submit as an HTML file

# %% [markdown]
# <font size = "5">
# Print your Emory ID below

# %%
print("2581997")
# Out:
# 2581997

# %% [markdown]
# <font size = "5">
#
# Import the numpy and matplotlib packages

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <font size = "5">
#
# (a) Compute a formula:
#
# <font size = "3">
#
# The formula for the volume of a cone is:
#
# <font size = "4">
#
# $V = \frac{1}{3} \pi r^2 h$
#
# <font size = "3">
#
# Where:
#
# - $V$ is the volume of the cone
# - $r$ is the radius of the base
# - $h$ is the height of the cone
#
# Calculate $V$ when:
#
# - $r = 5$
# - $h = 10$
#
#
# To get full points:
# - First define each of these variables
# - Write the formula above
# - Print out the result

# %%
# Variables
r = 5 #radius of the base 
h = 10 #height of the cone
V #volume of cone

# Formula for volume of a cone
V = (1/3) * np.pi * (r ** 2) * h

# Printing out calculated result
print(V)
# Out:
# 261.79938779914943

# %% [markdown]
# <font size = "5">
#
# (b) Composite operations on arrays
#
# <font size = "3">
#
# - Define r = 0.1
# - Define x = 1
# - Define two arrays $A$ and $T$ using "np.array()", assigning the following values
# $ a = \begin{pmatrix} a_1 \\ a_2 \\ a_3 \end{pmatrix} = \begin{pmatrix} 28 \\ 32 \\ 11 \end{pmatrix}, \qquad t = \begin{pmatrix} t_1 \\ t_2 \\ t_3 \end{pmatrix} = \begin{pmatrix} 4 \\ 5 \\ 6 \end{pmatrix} $
#
# - Use element-by-element vector operations to compute a new array $M$ of length 3:
# $ M = \begin{pmatrix} a_1 \cdot (1+r)^{t_1} + cos(x) \\ a_2 \cdot (1+r)^{t_2} + cos(x) \\ a_3 \cdot (1+r)^{t_3} + cos(x) \end{pmatrix} $
#
# - Compute the sum of the values of $M$ using "M.sum()"
# Note: I am using subscripts to denote the individual elements of $a$ and $t$.
#
# - In the code just enter the values of $a$ and $t$.
# - To get full points you must do all of the above tasks

# %%
# Defining variables
r = 0.1 
x = 1 

# Creating arrays A and T
a = np.array([28, 32, 11])
t = np.array([4, 5, 6])

M = (a * ((1 + r) ** t) + np.cos(x))

print(M) #checking the array

# Sum of the values of array M
print(M.sum())
# Out:
# [41.53510231 52.07662231 20.02747331]
# 113.63919791760446

# %% [markdown]
# <font size = "5">
#
# (c) Plot a normal random variable
# <font size = "3">
#
# To get full points:
#
# - Set a seed using "np.random.seed()"
# - Create the random variable with the following parameters
# - mean = 233, standard deviation = 99, and size = 1314
#
# - Create a histogram
# - Label the axes

# %%
np.random.seed(12345)

# Defining variables
mean = 233
sd = 99
size = 1314

data = np.random.normal(mean, sd, size)

# Creating histogram with labels
plt.hist(data)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram of Normal Random Variable")
# Out:
# Text(0.5, 1.0, 'Histogram of Normal Random Variable')

# %% [markdown]
# <font size = "5">
#
# (d) Checking whether word is part of list
#
# <font size = "3">
#
# - Define a variable "QSS" with the value "Statistics"
# - Define a list of fruits with the values list_QSS = ["Statistics", "CS", "Dara Science", "Math"]
# - Write an expression to test whether "QSS" is contained in "list_QSS"
#
# Hint: Use the "in" command. The final output should be True/False.
#
# To get full points run all of the above commands

# %%
# Defining variable and list 
QSS = "Statistics" 
list_QSS = ["Statistics", "CS", "Dara Science", "Math"]

# Checking whether QSS is in list_QSS
QSS in list_QSS
# Out:
# True

# %% [markdown]
# <font size = "5">
#
# (e) Classifying a variable
#
# <font size = "3">
#
# - Define a new variable "film_score" and assign it "70"
# - Write an if/else statement that does the following
#     - print("Box-office Success") if the score is strictly above 80.
#     - print("Intermediate Range") if the score is weakly less than 80 and strictly above 20.
#     - print("Box-office Failure") if the score does not fit in the above categories.
#
#
# To get full points you must do all of the above instructions

# %%
film_score = 70

#if/else statement for film_score
if film_score > 80: 
    print("Box-office Success")
elif (film_score <= 80) & (film_score > 20):
    print("Intermediate Range")
else:
    print("Box-office Failure")
# Out:
# Intermediate Range
